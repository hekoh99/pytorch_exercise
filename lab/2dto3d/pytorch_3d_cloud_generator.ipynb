# %%
# !git clone https://github.com/lkhphuc/pytorch-3d-point-cloud-generation.git
# Out:
# Cloning into 'pytorch-3d-point-cloud-generation'...
# remote: Enumerating objects: 323, done.
# remote: Total 323 (delta 0), reused 0 (delta 0), pack-reused 323
# Receiving objects: 100% (323/323), 380.78 KiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
cd /content/pytorch-3d-point-cloud-generation
# Out:
# /content/pytorch-3d-point-cloud-generation

# %%
# !wget https://cmu.box.com/shared/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Out:
# --2022-11-28 01:04:47--  https://cmu.box.com/shared/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Resolving cmu.box.com (cmu.box.com)... 74.112.186.144
# Connecting to cmu.box.com (cmu.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz [following]
# --2022-11-28 01:04:47--  https://cmu.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Reusing existing connection to cmu.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cmu.app.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz [following]
# --2022-11-28 01:04:48--  https://cmu.app.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Resolving cmu.app.box.com (cmu.app.box.com)... 74.112.186.144
# Connecting to cmu.app.box.com (cmu.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl2.boxcloud.com/d/1/b1!CMc6kw0AAet5bRDtX_WrZCl89lUa649ZGwN1M7SyRxAEwFf9Seb5U61KtuCiIrtBSjlp6G7EHgG5y1WDgI9M2VS3vVpupEnCZYSQ4ZPdOcd25EGwKeCsyDuquZR2iBNWFQ-9CpRA4Uew49ABYvDq7-UBbngKGjwRTeoMoSKrXn-7deW4GWW3-oj_TY34IVkeVbLgY4YQmrkkXbd5qyBymfmaWVJvGOSk3iHLbJNNk4yrlYAJCcWvvxndUwUe0ZCgTw5tfZqdHa169OLyXr_xw1n6S2p9GIVXHaaM8ESMd_Ztr9ubjfMoeZbSUhJff-mRW7MWZ8cIle1QMut1ZMlx3Xp4teQFjUH0c1Yx0Hf-76q0YflNTPk4gTWxJexthseY60U_meOP7TYHmM3mCmEeR3X-bvkKBcZh6-_0TWzYgy608-c03vFDGjWCSecq7zcgWBJUpuGYb8t9KdzBHfLDojQJArT3RCbelTjys50v1cE6tXzEKcb-oxPygKZuN_04TlgU1evSlsm4estmCPZbaaYmc_yd1DVnaX5UbfqXUxMy5H2mbRmdQXOTVAnhaASdCF90wsLifZxkjknD0dG2jusQzjfNJuH6LJ8YZu_NuALqhEm-F2BlPZ_ebjAXYfFT1Czl10vnjvqkmLsbmwyeDvC7VWL9Mt2aatuJQGIH5rr_JeJRoCsW7r3B8Oyv633LAYZwTmkfcec5qt7VoqveE-swfgopeSFkpb7QEXoQ-A2tUMqwyHhCC0fuvaGwmBjp2txzne_8c-AdB3p2iPJllho06P0xWDSSPOmQHRv7hJ-b--58eoq1qJ3ST2LVUFl6WXcbSRfQARoSG9X_wwnRkX6lENknqKp57NTtUryLbk_Hvz5FwgMpaRRJ8rNYNbX59tVSIrBlOUhjKj0EuBRfuHVth81U80vn-92OxOBWN9vEqRYn8OSjSHY4ewfSsLYJNdAobk2uF2OIO_g2RlmQev6FAVq1-Y0Fpqm1xJ4agA_iUTT-tIfmUc4qN5iDho0ncZFOsWoNvXCQbdEbmhyUWhOYuVoGQPcmByxK0JJObTA7eMX5-AWh1gk64gBOtZbkHG1dGs6SMwwLGt7QHmYMEw1xzrB7A1XVj-rnocrSl9C2c9ecp6sp8dVbjhI3KaSwsbg_Nf2uQifPrpXRZxiwaIc-GF
download
# Resolving dl2.boxcloud.com (dl2.boxcloud.com)... 74.112.186.128
# Connecting to dl2.boxcloud.com (dl2.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9399012334 (8.8G) [application/octet-stream]
# Saving to: ‘s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz’
#
# s4lkm5ej7sh4px72ves 100%[===================>]   8.75G  9.90MB/s    in 16m 0s
#
# 2022-11-28 01:20:49 (9.33 MB/s) - ‘s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz’ saved [9399012334/9399012334]

# %%
# !tar -zxf s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz

# %%
# !python3 data.py
# Out:
# EXPERIMENT: PCG_0
# ------------------------------------------
# input:64x64, output:128x128, pred:128x128
# viewN:8(out), upscale:5, novelN:5
# Device: cuda:0, depth_loss weight:1.0
# ------------------------------------------

# %%
# !ls
# Out:
# custom_scheduler.py  findLR_stg2.py			  scripts
# data		     options.py				  trainer.py
# data.py		     PCGModel.py			  train_stg1.py
# densify		     __pycache__			  train_stg2.py
# evaluate_dist.py     README.md				  transform.py
# evaluate.py	     render				  utils.py
# findLR_stg1.py	     s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 31.8 MB/s
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1

# %%
cd /content/pytorch-3d-point-cloud-generation
# Out:
# /content/pytorch-3d-point-cloud-generation

# %%
# !bash scripts/train_stg1.sh
# Out:
# =======================================================
# Pretrain structure generator with fixed viewpoints
# =======================================================
# Traceback (most recent call last):
#   File "train_stg1.py", line 11, in <module>
#     cfg = options.get_arguments()
#   File "/content/pytorch-3d-point-cloud-generation/options.py", line 162, in get_arguments
#     [0, 0, 0, 1]]).float().to(cfg.device)
# RuntimeError: CUDA error: invalid device ordinal
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
# !bash scripts/evaluate.sh
# Out:
# =======================================================
# Evaluate / generate 3D Point Cloud generation model.
# =======================================================
# EXPERIMENT: ORIG_STG2_sgd_trueWD_restart_cont1
# ------------------------------------------
# input:64x64, output:128x128, pred:128x128
# viewN:8(out), upscale:5, novelN:5
# Device: cuda:0, depth_loss weight:1.0
# ------------------------------------------
# Load fixed (stg1) data for category: 03001627
# batch size:24, chunk size: 32
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Traceback (most recent call last):
#   File "evaluate.py", line 21, in <module>
#     model = utils.build_structure_generator(cfg).to(cfg.device)
#   File "/content/pytorch-3d-point-cloud-generation/utils.py", line 104, in build_structure_generator
#     model.load_state_dict(torch.load(f"{LOAD_PATH}/best.pth"))
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'models/ORIG_STG2_sgd_trueWD_restart_cont1/best.pth'

# %%
cd ./densify
# Out:
# /content/pytorch-3d-point-cloud-generation/densify

# %%
# !ls
# Out:
# custom_scheduler.py  findLR_stg2.py  s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# data		     options.py      scripts
# data.py		     PCGModel.py     trainer.py
# densify		     __pycache__     train_stg1.py
# evaluate_dist.py     README.md	     train_stg2.py
# evaluate.py	     render	     transform.py
# findLR_stg1.py	     results	     utils.py

# %%
# !bash run.sh 03001627
# Out:
# Traceback (most recent call last):
#   File "densify.py", line 29, in <module>
#     V,E,F = util.parseObj(shape_file)
#   File "/content/pytorch-3d-point-cloud-generation/densify/util.py", line 6, in parseObj
#     with open(fname) as file:
# FileNotFoundError: [Errno 2] No such file or directory: '/dataset/ShapeNetCore.v2/03001627/1006be65e7bc937e9141f9b58470d646/models/model_normalized.obj'
