# %%
# !git clone https://github.com/lkhphuc/pytorch-3d-point-cloud-generation.git
# Out:
# Cloning into 'pytorch-3d-point-cloud-generation'...
# remote: Enumerating objects: 323, done.
# remote: Total 323 (delta 0), reused 0 (delta 0), pack-reused 323
# Receiving objects: 100% (323/323), 380.78 KiB | 12.69 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
cd /content/pytorch-3d-point-cloud-generation
# Out:
# /content/pytorch-3d-point-cloud-generation

# %%
# !wget https://cmu.box.com/shared/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Out:
# --2022-08-31 02:05:10--  https://cmu.box.com/shared/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Resolving cmu.box.com (cmu.box.com)... 74.112.186.144
# Connecting to cmu.box.com (cmu.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz [following]
# --2022-08-31 02:05:10--  https://cmu.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Reusing existing connection to cmu.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cmu.app.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz [following]
# --2022-08-31 02:05:11--  https://cmu.app.box.com/public/static/s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Resolving cmu.app.box.com (cmu.app.box.com)... 74.112.186.144
# Connecting to cmu.app.box.com (cmu.app.box.com)|74.112.186.144|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl2.boxcloud.com/d/1/b1!a7wh4QQoVHV1azG03kj1Jy5kN02IcuTd3OkHgSLF1XeWvxk0jKbBj2ZlCPOMuEKsat8b4M3wyj6jenunezXUQXvYrGyyrm0LEB_g9V-pV7BIafSCavLJ9bJ0GdHlooZGitzvqYlhDZBlF9DwQSN7Dcr3PLtZqOBWGAuPlzsb6NHIsRJnRgOiOO0kb1vV-8dSuaPKbzhLqkqftINg1vGHxNNnX6mMaTl_EWsESyxTl1BDJTZ6DfgJyJnNv0DATMcA1H6FxwULo9OFVmtSCIdpsRSnqAhotEydLPz9gjcpCpzg24Gloy5qAmnaS5z69pkY2WS1UpFyqwm7wGZEG35wVdPRp8Z4KVn9hwwHtQKfdZcPfo99wmgFBTJWuvN3Z6ZI4raw-pSlCDeV47O9acLA_e3M-FQMJqQu_v75USpsh6dfWmkUIj8cHsxwXXPhu-EKXIwBiYeSaa2l6U7_YCiAsILjbMX8PafEGdeSHl7YhPIB7-KNl_9GS7iV2yXu1gRveZAmf-G6XzwGlxJiooGXQnQsCXTQJdq5sh2bOkPZaVN976xdidubU-prU1x-3xca91YosSQwqg35Z2-q9CLi53BECu-yCSTePNy8a3Y1iNcIj_KbD_QSQDuSdVWbh6-6YlSzxKX0ETAIcnrGHg3lpi7aYJSYtq_Y9LWXb5djRW4ZB5YAgq-U6nvLJ_AODP5iYnRPlipDe_h92mxVh1QWlBWBpypMIs08l2Ald81tcq5fJ8LZB7LuadkX6FxAmaQDFCLt20eoQoLb_1EqYVbunBG0imEGEpJwozuE2197W3ZEQHA4KNgN6vdUk0BzgVnbgs31bCXeExDy71sIZHW0Mjnq-SjYDFuGVC60p0yTBHg47VtjhPR5xvMcs9ckdMX3mF8lwMCtMEY7yOT8JCrp3mcrphwblCQF8M-FIDNA5id5TaNMfDk99vzBnKLyHPlAObH_2S1b
X3mF8lwMCtMEY7yOT8JCrp3mcrphwblCQF8M-FIDNA5id5TaNMfDk99vzBnKLyHPlAObH_2S1bOXe0Lhh3P-GX7vBaC-SVAO82ZFj67jweMGz9ZMnrlHdRg86UKT7-H-zgFDXWuds_1axwSKp6xdVKLQdgh05FMzpO_10Woiz70_I3SQlgNdFthn0Sp9No6Aam9dIf5Sw07Opv6P1b-381qf2sUXzS-e9FLmrvzuNS7WSuwFlFFzIjSItT2sFQt0BHePsUxjkngRlTrAdXhzZt8ljCT6dGANDz-zNmPDOqcrAFpISe0QPSIanSytPi2WWEzdq86rJ7eohlz2COdsVah94Q6p14apZ6DDnwzl4yhRYEj_NRwbhNXSt_Z1PzqJxxhxNIrrRWXscWvHLivfNbHNvr0YZdTA3TuIY_V0qwvFsNQ8IMAbJgbVRVTGIUBoHfitQS-9z0_I9GvKLovawcYdE8PhJfK78IHgHBP_59JM-1OGaRsT5rJF4AgwCUvGiHcOhB-V31xUHF28_oP6SugTXRrxBccPDbuJv339xqZpigYV25oXJp3FtcKdYWt6LAXViQuZuW2WSoHAQUxvDgjs8./download
# Resolving dl2.boxcloud.com (dl2.boxcloud.com)... 74.112.186.128
# Connecting to dl2.boxcloud.com (dl2.boxcloud.com)|74.112.186.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9399012334 (8.8G) [application/octet-stream]
# Saving to: ‘s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz’
#
# s4lkm5ej7sh4px72ves 100%[===================>]   8.75G  11.7MB/s    in 15m 27s
#
# 2022-08-31 02:20:39 (9.67 MB/s) - ‘s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz’ saved [9399012334/9399012334]

# %%
# !tar -zxf s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz
# Out:
# tar (child): s4lkm5ej7sh4px72vesr17b1gxam4hgy.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !python3 data.py
# Out:
# EXPERIMENT: PCG_0
# ------------------------------------------
# input:64x64, output:128x128, pred:128x128
# viewN:8(out), upscale:5, novelN:5
# Device: cuda:0, depth_loss weight:1.0
# ------------------------------------------

# %%
# !ls
# Out:
# 03001627.list  densify.py  example.png	run.sh	util.py

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboardX
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 23.7 MB/s
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5.1

# %%
# !bash scripts/evaluate.sh
# Out:
# =======================================================
# Evaluate / generate 3D Point Cloud generation model.
# =======================================================
# EXPERIMENT: ORIG_STG2_sgd_trueWD_restart_cont1
# ------------------------------------------
# input:64x64, output:128x128, pred:128x128
# viewN:8(out), upscale:5, novelN:5
# Device: cuda:0, depth_loss weight:1.0
# ------------------------------------------
# Load fixed (stg1) data for category: 03001627
# batch size:24, chunk size: 32
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Traceback (most recent call last):
#   File "evaluate.py", line 21, in <module>
#     model = utils.build_structure_generator(cfg).to(cfg.device)
#   File "/content/pytorch-3d-point-cloud-generation/utils.py", line 104, in build_structure_generator
#     model.load_state_dict(torch.load(f"{LOAD_PATH}/best.pth"))
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'models/ORIG_STG2_sgd_trueWD_restart_cont1/best.pth'

# %%
# !cd ./densify

# %%
# !bash ./run.py 03001627
