# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pickle
path = '/content/drive/MyDrive/Colab_Notebooks/pytorch/code/lab/plenoptic/data/model_output/'
output_path = path + 'SOLO_output/003.pickle'

with open(output_path, 'rb') as fr:
  data = pickle.load(fr)
print(data)
# Out:
# [(tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
# ...

# %%
import pickle
path = '/content/drive/MyDrive/Colab_Notebooks/pytorch/code/lab/plenoptic/data/model_output/'
output_path = path + 'SOLO_output/014.pickle'

with open(output_path, 'rb') as fr:
  data = pickle.load(fr)
print(data)
# Out:
# [(tensor([[[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False]],
#
#         [[False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          [False, False, False,  ..., False, False, False],
#          ...,
# ...

# %%
import numpy as np
import pickle
path = '/content/drive/MyDrive/Colab_Notebooks/pytorch/code/lab/plenoptic/data/model_output/'
output_path = path + 'softTeacher_output/000.npy'
with open(output_path, 'rb') as fr:
  data = pickle.load(fr)
print(data)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-5-e05377031088> in <module>()
#       4 output_path = path + 'softTeacher_output/000.npy'
#       5 with open(output_path, 'rb') as fr:
# ----> 6   data = pickle.load(fr)
#       7 print(data)
#
# UnpicklingError: STACK_GLOBAL requires str
