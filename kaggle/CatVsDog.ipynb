# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#%matplotlib inline 

import os
from sys import path
from zipfile import ZipFile

from tqdm import tqdm
from PIL import Image

import torch
import torch.nn as nn
from torch.utils.data import Dataset , DataLoader
from torchvision import transforms
from torch.optim import Adam
from torch.autograd import Variable

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
train_path = "./train/"
test_path = "./test1/"

print(device)
# Out:
# cuda

# %%
class CatandDogSet(Dataset):
    def __init__(self, path):
        self.path = path
        self.img_name = os.listdir(self.path)
                
    def __len__(self):
        return len(self.img_name)
    
    def __getitem__(self, idx):
        img_idx = self.img_name[idx]
        img_item_path = os.path.join(self.path, img_idx)
        img = Image.open(img_item_path)
        label = img_idx.split(".")[0]
        return img, label, img_item_path

# %%
with ZipFile('./train.zip', 'r') as zip_ref:
    zip_ref.extractall('.')
with ZipFile('./test1.zip', 'r') as zip_ref:
    zip_ref.extractall('.')
    
# !ls
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-19-09708f127b02> in <module>()
# ----> 1 with ZipFile('./train.zip', 'r') as zip_ref:
#       2     zip_ref.extractall('.')
#       3 with ZipFile('./test1.zip', 'r') as zip_ref:
#       4     zip_ref.extractall('.')
#       5
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
#    1324         if not endrec:
# -> 1325             raise BadZipFile("File is not a zip file")
#    1326         if self.debug > 1:
#    1327             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
dataset = CatandDogSet(train_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e87ec24b96a3> in <module>()
# ----> 1 dataset = CatandDogSet(train_path)
#
# <ipython-input-4-c70b24bd27e2> in __init__(self, path)
#       2     def __init__(self, path):
#       3         self.path = path
# ----> 4         self.img_name = os.listdir(self.path)
#       5
#       6     def __len__(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: './train/'
